# %%
api_key = "pgOoL9bZd7fECCM4vgxpUwah5BxyGQJU0WoNKW0a"

# %%
import requests
url = "https://api.nasa.gov/planetary/apod?api_key="+api_key
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
data = response.json()
print(data)
# Out:
# {'date': '2026-05-29', 'explanation': "A gorgeous spiral galaxy, Messier 104 is famous for its nearly edge-on profile featuring a broad ring of obscuring dust lanes. Seen in silhouette against an extensive central bulge of stars, the swath of cosmic dust lends a broad brimmed hat-like appearance to the galaxy suggesting a more popular moniker, the Sombrero Galaxy. Also known as NGC 4594, the Sombrero galaxy can be seen across the spectrum and is host to a central supermassive black hole. About 50,000 light-years across and 28 million light-years away, M104 is one of the largest galaxies at the southern edge of the Virgo Galaxy Cluster. Still, the spiky foreground stars in this field of view lie well within our own Milky Way. This broad view of the well-known galaxy was processed to reveal M104's extended halo, as well as a faint tidal stellar stream. It was captured by the Dark Energy Camera (DECam) on the Blanco 4-meter telescope at the Cerro Tololo Inter-American Observatory.", 'hd
# ...

# %%
import json
print(json.dumps(data, indent=5))
# Out:
# {
#      "date": "2026-05-29",
# ...

# %%
print(data['hdurl'])
# Out:
# https://apod.nasa.gov/apod/image/2605/M104noirlab2612a.jpg

# %%
print(data['explanation'])
# Out:
# A gorgeous spiral galaxy, Messier 104 is famous for its nearly edge-on profile featuring a broad ring of obscuring dust lanes. Seen in silhouette against an extensive central bulge of stars, the swath of cosmic dust lends a broad brimmed hat-like appearance to the galaxy suggesting a more popular moniker, the Sombrero Galaxy. Also known as NGC 4594, the Sombrero galaxy can be seen across the spectrum and is host to a central supermassive black hole. About 50,000 light-years across and 28 million light-years away, M104 is one of the largest galaxies at the southern edge of the Virgo Galaxy Cluster. Still, the spiky foreground stars in this field of view lie well within our own Milky Way. This broad view of the well-known galaxy was processed to reveal M104's extended halo, as well as a faint tidal stellar stream. It was captured by the Dark Energy Camera (DECam) on the Blanco 4-meter telescope at the Cerro Tololo Inter-American Observatory.

# %%
import requests
url = "https://api.nasa.gov/planetary/apod?api_key="+api_key
response = requests.get(url, params={'count':10})
data = response.json()
print(data)
# Out:
# [{'copyright': 'Tunc Tezel', 'date': '2019-05-04', 'explanation': "On February 2nd early morning risers saw Saturn near an old Moon low on the eastern horizon. On that date bright planet, sunlit crescent, and faint lunar night side were captured in this predawn skyscape from Bursa, Turkey. Of course the Moon's ashen glow is earthshine, earthlight reflected from the Moon's night side. A description of earthshine, in terms of sunlight reflected by Earth's oceans illuminating the Moon's dark surface, was written over 500 years ago by Leonardo da Vinci. On May 2nd an old Moon also rose in the predawn twilight. On that date its ashen glow shared the sky with Venus, the brilliant morning star. May 2nd also marked the 500th anniversary of Leonardo's death in 1519.", 'hdurl': 'https://apod.nasa.gov/apod/image/1905/20190202tezel.jpg', 'media_type': 'image', 'service_version': 'v1', 'title': 'Saturn and the Da Vinci Glow', 'url': 'https://apod.nasa.gov/apod/image/1905/20190202tezel_1024.jpg'},
# ...

# %%
print(json.dumps(data, indent=5))
# Out:
# [
#      {
#           "copyright": "Tunc Tezel",
#           "date": "2019-05-04",
#           "explanation": "On February 2nd early morning risers saw Saturn near an old Moon low on the eastern horizon. On that date bright planet, sunlit crescent, and faint lunar night side were captured in this predawn skyscape from Bursa, Turkey. Of course the Moon's ashen glow is earthshine, earthlight reflected from the Moon's night side. A description of earthshine, in terms of sunlight reflected by Earth's oceans illuminating the Moon's dark surface, was written over 500 years ago by Leonardo da Vinci. On May 2nd an old Moon also rose in the predawn twilight. On that date its ashen glow shared the sky with Venus, the brilliant morning star. May 2nd also marked the 500th anniversary of Leonardo's death in 1519.",
#           "hdurl": "https://apod.nasa.gov/apod/image/1905/20190202tezel.jpg",
#           "media_type": "image",
#           "service_version": "v1",
# ...

# %%
name = []
url = []
explanation = []
for i in data:
    name.append(i['title'])
    url.append(i['url'])
    explanation.append(i['explanation'])

# %%
import pandas as pd
df = pd.DataFrame({
    'name':name,
    'url':url,
    'explanation':explanation
})

# %%
df
# Out:
#                                          name  \
# 0                Saturn and the Da Vinci Glow
# 1  NGC 4697: X-Rays from an Elliptical Galaxy
# 2                Inverted City Beneath Clouds
# 3             Moon and Planets in the Morning
# 4               X-Rays from the Galactic Core
# 5          In the Center of the Lagoon Nebula
# 6                     Planets Over Stonehenge
# 7                    M44: The Beehive Cluster
# 8          Spiral Galaxy NGC 3370 from Hubble
# 9                          Moon Occults Venus
#
#                                                  url  \
# 0  https://apod.nasa.gov/apod/image/1905/20190202...
# 1  https://apod.nasa.gov/apod/image/0206/ngc4697_...
# 2  https://apod.nasa.gov/apod/image/2006/ChicagoC...
# 3  https://apod.nasa.gov/apod/image/0910/3Planets...
# 4  https://apod.nasa.gov/apod/image/0411/mwcore_c...
# 5  https://apod.nasa.gov/apod/image/0810/lagoon_h...
# 6  https://apod.nasa.gov/apod/image/0205/planets1...
# ...

# %%
api_key = '3beddd7f21592afe5787c62211bca984'
url = "http://api.openweathermap.org/geo/1.0/direct?q=Ahmedabad&limit=5&appid="+api_key
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
data = response.json()
print(data)
# Out:
# [{'name': 'Ahmedabad', 'local_names': {'ru': 'Ахмадабад', 'uk': 'Ахмедабад', 'or': 'ଅହମଦାବାଦ', 'ta': 'அகமதாபாத்', 'bn': 'আহমেদাবাদ', 'hi': 'अहमदाबाद', 'ur': 'احمد آباد', 'de': 'Ahmedabad', 'feature_name': 'Ahmedabad', 'pa': 'ਅਹਿਮਦਾਬਾਦ', 'zh': '艾哈迈达巴德', 'pl': 'Ahmadabad', 'eo': 'Ahmadabado', 'gu': 'અમદાવાદ', 'kn': 'ಅಹ್ಮದಾಬಾದ್', 'ml': 'അഹമ്മദാബാദ്', 'oc': 'Ahmadabad', 'cs': 'Ahmadábád', 'he': 'אחמדאבאד', 'ascii': 'Ahmedabad', 'ne': 'अहमदाबाद', 'ja': 'アフマダーバード', 'tt': 'Әхмәтабад', 'ar': 'أحمد آباد', 'mr': 'अहमदाबाद', 'en': 'Ahmedabad', 'te': 'అహ్మదాబాద్'}, 'lat': 23.0215374, 'lon': 72.5800568, 'country': 'IN', 'state': 'Gujarat'}, {'name': 'Ahmedabad', 'local_names': {'en': 'Ahmedabad'}, 'lat': 32.5022729, 'lon': 72.8536319, 'country': 'PK', 'state': 'Punjab'}, {'name': 'Ahmedabad', 'local_names': {'en': 'Ahmedabad'}, 'lat': 24.7312039, 'lon': 67.6891818, 'country': 'PK', 'state': 'Sindh'}, {'name': 'Ahmedabad', 'lat': 32.9649355, 'lon': 74.2725539, 'country': 'PK', 'state': 'Azad Kashm
# ...

# %%
print(json.dumps(data, indent=5))
# Out:
# [
#      {
#           "name": "Ahmedabad",
#           "local_names": {
#                "ru": "\u0410\u0445\u043c\u0430\u0434\u0430\u0431\u0430\u0434",
#                "uk": "\u0410\u0445\u043c\u0435\u0434\u0430\u0431\u0430\u0434",
#                "or": "\u0b05\u0b39\u0b2e\u0b26\u0b3e\u0b2c\u0b3e\u0b26",
#                "ta": "\u0b85\u0b95\u0bae\u0ba4\u0bbe\u0baa\u0bbe\u0ba4\u0bcd",
#                "bn": "\u0986\u09b9\u09ae\u09c7\u09a6\u09be\u09ac\u09be\u09a6",
#                "hi": "\u0905\u0939\u092e\u0926\u093e\u092c\u093e\u0926",
#                "ur": "\u0627\u062d\u0645\u062f \u0622\u0628\u0627\u062f",
#                "de": "Ahmedabad",
#                "feature_name": "Ahmedabad",
#                "pa": "\u0a05\u0a39\u0a3f\u0a2e\u0a26\u0a3e\u0a2c\u0a3e\u0a26",
#                "zh": "\u827e\u54c8\u8fc8\u8fbe\u5df4\u5fb7",
#                "pl": "Ahmadabad",
#                "eo": "Ahmadabado",
#                "gu": "\u0a85\u0aae\u0aa6\u0abe\u0ab5\u0abe\u0aa6",
# ...

# %%
lat = data[0]['lat']
lon = data[0]['lon']
print(lat)
print(lon)
# Out:
# 23.0215374
# 72.5800568

# %%
url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}.99&appid={api_key}&units=metric"
response = requests.get(url)
print(url)
response = requests.get(url)
print(response)
# Out:
# https://api.openweathermap.org/data/2.5/weather?lat=23.0215374&lon=72.5800568.99&appid=3beddd7f21592afe5787c62211bca984&units=metric
# <Response [400]>

# %%
data = response.json()
print(data)
# Out:
# {'cod': '400', 'message': 'wrong longitude'}

# %%
url = f"http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={api_key}&units=metric"
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
data=response.json()
print(data)
# Out:
# {'coord': {'lon': 72.5801, 'lat': 23.0215}, 'list': [{'main': {'aqi': 2}, 'components': {'co': 95.91, 'no': 0.17, 'no2': 0.79, 'o3': 62.61, 'so2': 1.36, 'pm2_5': 7.8, 'pm10': 32.03, 'nh3': 0.62}, 'dt': 1780035001}]}

# %%
print(json.dumps(data, indent=5))
# Out:
# {
#      "coord": {
#           "lon": 72.5801,
#           "lat": 23.0215
#      },
#      "list": [
#           {
#                "main": {
#                     "aqi": 2
#                },
#                "components": {
#                     "co": 95.91,
#                     "no": 0.17,
#                     "no2": 0.79,
#                     "o3": 62.61,
#                     "so2": 1.36,
#                     "pm2_5": 7.8,
#                     "pm10": 32.03,
#                     "nh3": 0.62
#                },
#                "dt": 1780035001
#           }
#      ]
# }

# %%
print(data['list'][0]["main"]["aqi"])
# Out:
# 2

# %%
url = f"https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={api_key}&units=metric"

# %%
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
data = response.json()
print(data)
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1780045200, 'main': {'temp': 37.66, 'feels_like': 39.88, 'temp_min': 37.66, 'temp_max': 42.89, 'pressure': 1005, 'sea_level': 1005, 'grnd_level': 998, 'humidity': 33, 'temp_kf': -5.23}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'clouds': {'all': 13}, 'wind': {'speed': 7.81, 'deg': 250, 'gust': 8.75}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2026-05-29 09:00:00'}, {'dt': 1780056000, 'main': {'temp': 39.72, 'feels_like': 41.37, 'temp_min': 39.72, 'temp_max': 42.06, 'pressure': 1003, 'sea_level': 1003, 'grnd_level': 996, 'humidity': 27, 'temp_kf': -2.34}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'clouds': {'all': 7}, 'wind': {'speed': 9, 'deg': 282, 'gust': 9.5}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2026-05-29 12:00:00'}, {'dt': 1780066800, 'main': {'temp': 34.83, 'feels_like': 36.07, 'temp_min'
# ...

# %%
print(json.dumps(data, indent=5))
# Out:
# {
#      "cod": "200",
#      "message": 0,
#      "cnt": 40,
#      "list": [
#           {
#                "dt": 1780045200,
#                "main": {
#                     "temp": 37.66,
#                     "feels_like": 39.88,
#                     "temp_min": 37.66,
#                     "temp_max": 42.89,
#                     "pressure": 1005,
#                     "sea_level": 1005,
#                     "grnd_level": 998,
#                     "humidity": 33,
#                     "temp_kf": -5.23
#                },
#                "weather": [
#                     {
#                          "id": 801,
#                          "main": "Clouds",
#                          "description": "few clouds",
#                          "icon": "02d"
#                     }
#                ],
#                "clouds": {
#                     "all": 13
#                },
#                "wind": {
#                     "speed": 7.81,
#                     "deg": 250,
# ...

# %%
date,temp,humidity, windspeed,time,discription = [],[],[],[],[],[]
list1 = data["list"]

# %%
for i in list1:
    date.append(i["dt_txt"].split(" ")[0])
    time.append(i["dt_txt"].split(" ")[1])
    temp.append(i["main"]["temp"])
    humidity.append(i["main"]["humidity"])
    windspeed.append(i["wind"]["speed"])
    discription.append(i["weather"][0]["description"])

# %%
df = pd.DataFrame({
    'date':date,
    'time':time,
    'temp':temp,
    'humidity':humidity,
    'windspeed':windspeed,
    'discription':discription

})

# %%
df
# Out:
#           date      time   temp  humidity  windspeed       discription
# 0   2026-05-29  09:00:00  37.66        33       7.81        few clouds
# 1   2026-05-29  12:00:00  39.72        27       9.00         clear sky
# 2   2026-05-29  15:00:00  34.83        37       7.65         clear sky
# 3   2026-05-29  18:00:00  31.32        56       6.01         clear sky
# 4   2026-05-29  21:00:00  30.43        57       6.51         clear sky
# 5   2026-05-30  00:00:00  29.17        65       6.29         clear sky
# 6   2026-05-30  03:00:00  31.49        56       7.82         clear sky
# 7   2026-05-30  06:00:00  38.00        30       7.65         clear sky
# 8   2026-05-30  09:00:00  42.30        21       7.85         clear sky
# 9   2026-05-30  12:00:00  41.89        21       7.60         clear sky
# 10  2026-05-30  15:00:00  36.28        36       5.55         clear sky
# 11  2026-05-30  18:00:00  33.55        46       5.48         clear sky
# ...

# %%
# %%writefile local.py
from flask import Flask, jsonify, request

app = Flask(__name__)

# Sample data
faculty = [
    {"id": 1, "name": "Rajesh", "dept": "Mechanical"},
    {"id": 2, "name": "Himanshu", "dept": "ECE"}
]

# ---------- GET ----------
@app.route('/faculty', methods=['GET'])
def get_faculty():
    return jsonify(faculty)


# ---------- POST ----------
@app.route('/faculty', methods=['POST'])
def add_faculty():

    data = request.json

    if "name" not in data or "dept" not in data:
        return jsonify({"message": "Name and Dept required"}), 400

    new_data = {
        "id": len(faculty) + 1,
        "name": data["name"],
        "dept": data["dept"]
    }

    faculty.append(new_data)

    return jsonify(new_data), 201


# ---------- PUT (Full Update) ----------
@app.route('/faculty/<int:id>', methods=['PUT'])
def put_faculty(id):

    data = request.json

    # PUT requires complete object
    if "name" not in data or "dept" not in data:
        return jsonify({"message": "Both name and dept required"}), 400

    for f in faculty:

        if f["id"] == id:

            f["name"] = data["name"]
            f["dept"] = data["dept"]

            return jsonify(f)

    return jsonify({"message": "Not found"}), 404


# ---------- PATCH (Partial Update) ----------
@app.route('/faculty/<int:id>', methods=['PATCH'])
def patch_faculty(id):

    data = request.json

    for f in faculty:

        if f["id"] == id:

            if "name" in data:
                f["name"] = data["name"]

            if "dept" in data:
                f["dept"] = data["dept"]

            return jsonify(f)

    return jsonify({"message": "Not found"}), 404


# ---------- DELETE ----------
@app.route('/faculty/<int:id>', methods=['DELETE'])
def delete_faculty(id):

    global faculty

    for f in faculty:

        if f["id"] == id:

            faculty.remove(f)

            return jsonify({"message": "Deleted successfully"})

    return jsonify({"message": "Not found"}), 404


# ---------- Run Server ----------
if __name__ == '__main__':
    app.run(debug=True,use_reloader=False)
# Out:
# Writing local.py

# %%
import requests
import json
url = "http://127.0.0.1:5000/faculty"
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
new_data = {
    "name" : "Dhairya",
    "dept" : "CSE_AI"
}
response = requests.post(url, json=new_data)
print(response)
# Out:
# <Response [201]>

# %%
print(response.json())
# Out:
# {'dept': 'CSE_AI', 'id': 4, 'name': 'Dhairya'}

# %%
new_data = {'dept': 'CSE_AI', 'name': 'Shrey'}
response = requests.put(url+"/1", json=new_data)
print(response)
# Out:
# <Response [200]>

# %%
new_data = {'dept': 'IT'}
response = requests.patch(url+"/4", json=new_data)
print(response)
# Out:
# <Response [200]>

# %%
response = requests.delete(url+"/3")
print(response)
# Out:
# <Response [200]>

# %%
url = "https://jsonplaceholder.typicode.com/posts"
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
data = response.json()
print(json.dumps(data, indent=4))
# Out:
# [
#     {
#         "userId": 1,
#         "id": 1,
#         "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#         "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
#     },
#     {
#         "userId": 1,
#         "id": 2,
#         "title": "qui est esse",
#         "body": "est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla"
#     },
#     {
#         "userId": 1,
#         "id": 3,
#         "title": "ea molestias quasi exercitationem repellat qui ipsa sit aut",
#         "body": "et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut"
#     },
# ...

# %%
print(response.status_code)
# Out:
# 200

# %%
print(len(data))
# Out:
# 100

# %%
params = {"_page":1,"_limit":10}

# %%
response = requests.get(url, params=params)
print(response)
# Out:
# <Response [200]>

# %%
data = response.json()
print(data)
# Out:
# [{'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}, {'userId': 1, 'id': 2, 'title': 'qui est esse', 'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'}, {'userId': 1, 'id': 3, 'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut', 'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'}, {'userId': 1, 'id': 4, 'title': 'eum et est occaecati', 'body': 'ullam et saepe reiciendis voluptatem adipisci\nsit amet autem assumenda provident rerum culpa\nquis hic
# ...

# %%
print(json.dumps(data, indent=4))
# Out:
# [
#     {
#         "userId": 1,
#         "id": 1,
#         "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#         "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
#     },
#     {
#         "userId": 1,
#         "id": 2,
#         "title": "qui est esse",
#         "body": "est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla"
#     },
#     {
#         "userId": 1,
#         "id": 3,
#         "title": "ea molestias quasi exercitationem repellat qui ipsa sit aut",
#         "body": "et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut"
#     },
# ...

# %%
url = "https://api.github.com/rate_limit"
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
data = response.json()
print(json.dumps(data, indent=4))
# Out:
# {
#     "resources": {
#         "code_search": {
#             "limit": 60,
#             "remaining": 57,
#             "reset": 1780044559,
#             "used": 3,
#             "resource": "code_search"
#         },
#         "core": {
#             "limit": 60,
#             "remaining": 57,
#             "reset": 1780044559,
#             "used": 3,
#             "resource": "core"
#         },
#         "graphql": {
#             "limit": 0,
#             "remaining": 0,
#             "reset": 1780044812,
#             "used": 0,
#             "resource": "graphql"
#         },
#         "integration_manifest": {
#             "limit": 5000,
#             "remaining": 5000,
#             "reset": 1780044812,
#             "used": 0,
#             "resource": "integration_manifest"
#         },
#         "search": {
#             "limit": 10,
#             "remaining": 10,
#             "reset": 1780041272,
#             "used": 0,
#             "resource": "search"
# ...
